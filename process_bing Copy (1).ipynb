# %% [markdown]
# Read the JSON file as a DataFrame

# %%
df = spark.read.option("multiline", "true").json("Files/bing-latest-news.json")
# df now is a Spark DataFrame containing JSON data from "Files/bing-latest-news.json".
display(df)
# Out:
# StatementMeta(, 26f212cd-c9af-44d0-a13c-eec767da529e, 53, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, c1903d5c-736d-4ba3-ac78-ec73078e1382)

# %% [markdown]
# Selecting just the value column from the dataframe

# %%
df= df.select("value")
# Out:
# StatementMeta(, 26f212cd-c9af-44d0-a13c-eec767da529e, 54, Finished, Available, Finished)

# %%
display(df)
# Out:
# StatementMeta(, 26f212cd-c9af-44d0-a13c-eec767da529e, 55, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, d17066b4-7104-4b55-a276-5fe871d43235)

# %% [markdown]
# Explode the JSON column

# %%
from pyspark.sql.functions import explode
df_exploded = df.select(explode(df["value"]).alias("json_object"))
# Out:
# StatementMeta(, 26f212cd-c9af-44d0-a13c-eec767da529e, 56, Finished, Available, Finished)

# %%
display(df_exploded)
# Out:
# StatementMeta(, 26f212cd-c9af-44d0-a13c-eec767da529e, 57, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 1add782a-c344-40c0-82c2-603df91b42ca)

# %% [markdown]
# Converting the Exploded JSON DataFrame to a single JSON String list

# %%
json_list = df_exploded.toJSON().collect()
# Out:
# StatementMeta(, 26f212cd-c9af-44d0-a13c-eec767da529e, 58, Finished, Available, Finished)

# %%
print(json_list)
# Out:
# StatementMeta(, 26f212cd-c9af-44d0-a13c-eec767da529e, 59, Finished, Available, Finished)
# ['{"json_object":{"about":[{"name":"Arsenal F.C.","readLink":"https://api.bing.microsoft.com/api/v7/entities/8b3b4135-cb8e-ded8-10ce-8f130d64b863"},{"name":"Paris Saint-Germain F.C.","readLink":"https://api.bing.microsoft.com/api/v7/entities/67266d4d-2667-f33f-7d3e-ae1225abff86"},{"name":"Ben Chilwell","readLink":"https://api.bing.microsoft.com/api/v7/entities/d7ca1fbb-f3df-3e53-cfa2-323dc6ffc2f4"},{"name":"Chelsea F.C.","readLink":"https://api.bing.microsoft.com/api/v7/entities/8346cd56-1a96-adb0-26e1-f3679d88e0ba"},{"name":"Enzo Maresca","readLink":"https://api.bing.microsoft.com/api/v7/entities/57f409e7-f3be-4c3f-89a8-adb2b541771b"},{"name":"Liverpool","readLink":"https://api.bing.microsoft.com/api/v7/entities/a5642e81-20ab-a561-17cc-52a63926b210"},{"name":"West Ham","readLink":"https://api.bing.microsoft.com/api/v7/entities/414af999-cc01-19ed-e90d-da7544f21d20"},{"name":"Tottenham","readLink":"https://api.bing.microsoft.com/api/v7/entities/91465437-b002-d662-c8a6-1c91a9732e03"},{"name":"Jadon Sancho","readLink":"https://api.bing.microsoft.com/api/v7/entities/f6c428ba-e5b1-b002-06da-e4dc3cc9497f"},{"name":"Manchester United F.C.","readLink":"https://api.bing.microsoft.com/api/v7/entities/064ce28e-ed07-a026-2f79-1b321d7548ea"}],"category":"Sports","datePublished":"2024-08-22T06:45:00.0000000Z","description":"United were said to have agreed terms with Paris Saint-Germain midfielder Manuel Ugarte months ago, only to see the deal stall – reportedly over a difference in valuation. Now, however, there could be a breakthrough,","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=OVFT.ZD8kbM1Ve_hTYnwsGZCJ9i&pid=News","height":429,"width":700}},"name":"Transfer news LIVE! Merino to Arsenal imminent; fresh Osihmen interest; Ugarte to Man Utd agreed; Chelsea","provider":[{"_type":"Organization","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=ODF.6dX1YSu3BLe3mNX-gZCcdA&pid=news"}},"name":"London Evening Standard"}],"url":"https://www.standard.co.uk/sport/football/transfer-news-live-arsenal-fc-chelsea-man-utd-liverpool-merino-osimhen-ugarte-b1177103.html"}}', '{"json_object":{"about":[{"name":"Manchester United F.C.","readLink":"https://api.bing.microsoft.com/api/v7/entities/064ce28e-ed07-a026-2f79-1b321d7548ea"},{"name":"Jadon Sancho","readLink":"https://api.bing.microsoft.com/api/v7/entities/f6c428ba-e5b1-b002-06da-e4dc3cc9497f"},{"name":"Premier League","readLink":"https://api.bing.microsoft.com/api/v7/entities/02bde011-1e9d-3aff-8309-7d07d4031798"},{"name":"Cincinnati Reds","readLink":"https://api.bing.microsoft.com/api/v7/entities/c1b7e6bd-bc88-07a2-0411-c1900be45f2a"},{"name":"Erik ten Hag","readLink":"https://api.bing.microsoft.com/api/v7/entities/a61e1753-9864-40c2-8860-7a57dde78c3a"}],"category":"Sports","datePublished":"2024-08-22T05:09:00.0000000Z","description":"Keep across all the latest Manchester United transfer news in the Manchester Evening News\' dedicated live blog","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=OVFT.o2_3-UpVKy0Bg4EiHJ0XLS&pid=News","height":367,"width":700}},"name":"Man United transfer news live Manuel Ugarte close and Jadon Sancho exit","provider":[{"_type":"Organization","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=ODF.oxaa8-w2MDoXi5yOUu7A3w&pid=news"}},"name":"Manchester Evening News"}],"url":"https://www.manchestereveningnews.co.uk/sport/football/transfer-news/man-united-transfer-news-live-29786474"}}', '{"json_object":{"about":[{"name":"Taylor Swift","readLink":"https://api.bing.microsoft.com/api/v7/entities/98004a38-a3ea-b902-b6d3-687b30b54353"},{"name":"Ryan Reynolds","readLink":"https://api.bing.microsoft.com/api/v7/entities/0f9e50fe-48fa-e040-0c90-775edca2beaa"},{"name":"Kamala Harris","readLink":"https://api.bing.microsoft.com/api/v7/entities/ef5cf66f-32b7-7271-286a-8e8313eda5c5"},{"name":"Communist Party USA","readLink":"https://api.bing.microsoft.com/api/v7/entities/471dd76f-8a52-c1ea-6b7f-2eafd5d664f4"},{"name":"Donald Trump","r ...

# %% [markdown]
# Testing the JSON string list

# %%
print(json_list[23])
# Out:
# StatementMeta(, 26f212cd-c9af-44d0-a13c-eec767da529e, 60, Finished, Available, Finished)
# {"json_object":{"datePublished":"2024-08-22T06:24:00.0000000Z","description":"Five bodies have been found in the search for those missing after a yacht sank off the Sicily coast, bringing the total number of dead to six. Search efforts for the final missing person are resuming for a fourth morning.","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=OVFT.rYTpkI5Y57586oDqgmOaxC&pid=News","height":393,"width":700}},"name":"Superyacht sinks latest: Search for final missing person - as identities of five bodies to be confirmed","provider":[{"_type":"Organization","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=ODF.Eg62H9DIbo-JYPI6GpAgGA&pid=news"}},"name":"Sky"}],"url":"https://news.sky.com/story/superyacht-sinks-latest-search-for-final-missing-person-as-identities-of-five-bodies-to-be-confirmed-13199663"}}

# %%
import json

news_json = json.loads(json_list[3]) # Converting the JSON string to a JSON dictionary
# Out:
# StatementMeta(, 26f212cd-c9af-44d0-a13c-eec767da529e, 61, Finished, Available, Finished)

# %%
print(news_json)
# Out:
# StatementMeta(, 26f212cd-c9af-44d0-a13c-eec767da529e, 62, Finished, Available, Finished)
# {'json_object': {'about': [{'name': 'Erik ten Hag', 'readLink': 'https://api.bing.microsoft.com/api/v7/entities/a61e1753-9864-40c2-8860-7a57dde78c3a'}, {'name': 'Jadon Sancho', 'readLink': 'https://api.bing.microsoft.com/api/v7/entities/f6c428ba-e5b1-b002-06da-e4dc3cc9497f'}, {'name': 'Manchester United F.C.', 'readLink': 'https://api.bing.microsoft.com/api/v7/entities/064ce28e-ed07-a026-2f79-1b321d7548ea'}, {'name': 'Borussia Dortmund', 'readLink': 'https://api.bing.microsoft.com/api/v7/entities/b12f84ff-3350-8fc4-0dc6-146456fdb333'}, {'name': 'Premier League', 'readLink': 'https://api.bing.microsoft.com/api/v7/entities/02bde011-1e9d-3aff-8309-7d07d4031798'}, {'name': 'Chelsea F.C.', 'readLink': 'https://api.bing.microsoft.com/api/v7/entities/8346cd56-1a96-adb0-26e1-f3679d88e0ba'}, {'name': 'The Athletic', 'readLink': 'https://api.bing.microsoft.com/api/v7/entities/1f67ac13-d1f9-e346-c50d-574e8700b97f'}], 'category': 'Sports', 'datePublished': '2024-08-22T07:42:07.0000000Z', 'description': 'It comes amid a proposed fire sale at Stamford Bridge as key figures upstairs attempt to generate some more cash for their own recruitment drive. Sancho is tipped to cost around £40million.', 'image': {'thumbnail': {'contentUrl': 'https://www.bing.com/th?id=OVFT.fJyErVidbcTdzHGomwbDKi&pid=News', 'height': 367, 'width': 700}}, 'mentions': [{'name': 'Transfer'}, {'name': 'Manchester Evening News'}, {'name': 'Manchester United F.C.'}], 'name': "Swap deal, PSG option, £40m 'approach' - Jadon Sancho Man United transfer latest", 'provider': [{'_type': 'Organization', 'image': {'thumbnail': {'contentUrl': 'https://www.bing.com/th?id=ODF.oxaa8-w2MDoXi5yOUu7A3w&pid=news'}}, 'name': 'Manchester Evening News on MSN.com'}], 'url': 'https://www.msn.com/en-gb/sport/other/swap-deal-psg-option-40m-approach-jadon-sancho-man-united-transfer-latest/ar-AA1pehqc'}}

# %%
print(news_json['json_object']['name'])
print(news_json['json_object']['description'])
print(news_json['json_object']['category'])
print(news_json['json_object']['url'])
print(news_json['json_object']['image']['thumbnail']['contentUrl'])
print(news_json['json_object']['provider'][0]['name'])
print(news_json['json_object']['datePublished'])
# Out:
# StatementMeta(, 26f212cd-c9af-44d0-a13c-eec767da529e, 63, Finished, Available, Finished)
# Swap deal, PSG option, £40m 'approach' - Jadon Sancho Man United transfer latest
# It comes amid a proposed fire sale at Stamford Bridge as key figures upstairs attempt to generate some more cash for their own recruitment drive. Sancho is tipped to cost around £40million.
# Sports
# https://www.msn.com/en-gb/sport/other/swap-deal-psg-option-40m-approach-jadon-sancho-man-united-transfer-latest/ar-AA1pehqc
# https://www.bing.com/th?id=OVFT.fJyErVidbcTdzHGomwbDKi&pid=News
# Manchester Evening News on MSN.com
# 2024-08-22T07:42:07.0000000Z

# %% [markdown]
# Processing the JSON property to List

# %%
title = []
description = []
category = []
url = []
image = []
provider = []
datePublished = []

#Process each JSON odbject in the list

for json_str in json_list:
    try:
        #Parse the JSON string into Dictionary
        article = json.loads(json_str)

        if article["json_object"].get("category") and article["json_object"].get("image", {}).get("thumbnail", {}).get("contentUrl", {}):

            #Extract information from dictionary
            title.append(article["json_object"]["name"])
            description.append(article["json_object"]["description"])
            category.append(article["json_object"]["category"])
            url.append(article["json_object"]["url"])
            image.append(article["json_object"]["image"]["thumbnail"]["contentUrl"])
            provider.append(article["json_object"]["provider"][0]["name"])
            datePublished.append(article["json_object"]["datePublished"])
    except Exception as e:
        print(f"Error processing JSON object:{e}")
print(title)
# Out:
# StatementMeta(, 26f212cd-c9af-44d0-a13c-eec767da529e, 64, Finished, Available, Finished)
# ['Transfer news LIVE! Merino to Arsenal imminent; fresh Osihmen interest; Ugarte to Man Utd agreed; Chelsea', 'Man United transfer news live Manuel Ugarte close and Jadon Sancho exit', 'Fake celebrity endorsements become latest weapon in misinformation wars, sowing confusion ahead of 2024 election', "Swap deal, PSG option, £40m 'approach' - Jadon Sancho Man United transfer latest", 'Lions star re-signs, Hawk rolls on, Port gun close to new deal', 'Everton transfer news LIVE - John Textor takeover agreement, Rafa Benitez claim', "Roman Wilson injury update: Latest news on Steelers WR's Week 1 status", "Trump accuses Biden admin of 'MASSIVE SCANDAL' after new jobs numbers dramatically revised downward", 'Borderlands 4: Release date speculation and latest news', 'Man Utd transfer news LIVE: Ugarte breakthrough as PSG agree fee, Chilwell offer, Branthwaite stance', 'Newcastle United transfer news LIVE - Edmond Tapsoba transfer clue, Guehi latest, exit tipped', 'Police raid Andrew Tate’s home in Romania as new allegations emerge involving minors', "New Jersey bill would offer tax deductions for E-ZPass tolls. Here's how it would work.", 'Transfer news LIVE! Merino to Arsenal; Man Utd agree Ugarte fee; Chelsea hijack; Liverpool, Spurs latest', 'Arsenal transfer news: Mikel Arteta sent warning as goalkeeper target breaks silence', 'Starbucks new boss under fire for 1,000 mile commute', 'Rep. Bill Pascrell Jr., 12-term New Jersey Democrat, dies at 87, his family says', "New Details Emerge About Richard Simmons' Cause of Death", "New York AG asks appeals court to uphold Trump's $454M fraud judgment", 'Pope Francis appoints new Ordinary for Armenian Catholics in Eastern Europe', 'Kamala Harris ushers in a new Democratic era, stepping out of Biden shadow', 'New iPhone Warning—Typing This Will Crash Your Device', 'Homes for Sale in New York and New Jersey', 'Canadian freight railroads shut down, dealing a potential blow to North America’s economy', 'Amanda Gorman performs new poem at DNC', 'Juan Soto embraced playing in New York spotlight right from the start', 'Dow Jones Today: Stocks Close Higher as S&P 500 Approaches New Record', 'Kamala Harris Not Leading a Single Battleground State in New Poll', 'Nancy Pelosi passes the torch to a new generation at Democratic convention']

# %% [markdown]
# Converting the List to a DataFrame

# %%
from pyspark.sql.types import StructType, StructField, StringType

# Combine the lists
data = list(zip(title, description,category,url,image, provider, datePublished))
# Define schema 
schema = StructType([
    StructField("title", StringType(), True),
    StructField("description", StringType(), True),
    StructField("category", StringType(), True),
    StructField("url", StringType(), True),
    StructField("image", StringType(), True),
    StructField("provider", StringType(), True),
    StructField("datePublished", StringType(), True),
])

# Create DataFrame
df_cleaned = spark.createDataFrame(data, schema=schema)
# Out:
# StatementMeta(, 26f212cd-c9af-44d0-a13c-eec767da529e, 65, Finished, Available, Finished)

# %%
display(df_cleaned)
# Out:
# StatementMeta(, 26f212cd-c9af-44d0-a13c-eec767da529e, 66, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, dddfcb8d-5c1f-44da-b121-158049ba357d)

# %% [markdown]
# Converting DatePublieshed column into Date Format

# %%
# Convert into Date Format
from pyspark.sql.functions import to_date, date_format
df_cleaned_final = df_cleaned.withColumn("datePublished", date_format(to_date("datePublished"), "dd-MMM-yyyy"))
# Out:
# StatementMeta(, 26f212cd-c9af-44d0-a13c-eec767da529e, 67, Finished, Available, Finished)

# %%
display(df_cleaned_final.limit(5))
# Out:
# StatementMeta(, 26f212cd-c9af-44d0-a13c-eec767da529e, 68, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 9565379e-13a2-48a2-9541-51584454c617)

# %% [markdown]
# Writing the Final DateFrame to the LakeHouse DB in a Delta format

# %%
# df_cleaned_final.write.format("delta").saveAsTable("bing_lake_db.tbl_latest_news")
# Out:
# StatementMeta(, 26f212cd-c9af-44d0-a13c-eec767da529e, 69, Finished, Available, Finished)

# %%
#Over write delta table
# df_cleaned_final.write.format("delta").mode('overwrite').saveAsTable("bing_lake_db.tbl_latest_news")
# Out:
# StatementMeta(, 26f212cd-c9af-44d0-a13c-eec767da529e, 70, Finished, Available, Finished)

# %%
# Appending latest data without over write exiting table data
# df_cleaned_final.write.format("delta").saveAsTable("bing_lake_db.tbl_latest_news")
# Out:
# StatementMeta(, 26f212cd-c9af-44d0-a13c-eec767da529e, 71, Finished, Available, Finished)

# %%
# %%sql
# SELECT count(*) from tbl_latest_news;
 # DELETE from TABLE tbl_latest_news;
# Out:
# StatementMeta(, 26f212cd-c9af-44d0-a13c-eec767da529e, 72, Finished, Available, Finished)

# %%
from pyspark.sql.utils import AnalysisException

try:
    table_name = 'bing_lake_db.tbl_latest_news1'
    df_cleaned_final.write.format("delta").saveAsTable(table_name)
except AnalysisException:
    print("Table Already Exits")

    df_cleaned_final.createOrReplaceTempView("vw_df_cleaned_final")

    spark.sql(f""" MERGE INTO {table_name} target_table
                   USING vw_df_cleaned_final source_view

                   ON source_view.url = target_table.url

                   WHEN MATCHED AND 
                   source_view.title <> target_table.title or
                   source_view.description <> target_table.description or
                   source_view.category <> target_table.category or
                   source_view.image <> target_table.image or
                   source_view.provider <> target_table.provider or
                   source_view.datePublished <> target_table.datePublished 

                   THEN UPDATE SET *

                   WHEN NOT MATCHED THEN INSERT *
                """)
# Out:
# StatementMeta(, 26f212cd-c9af-44d0-a13c-eec767da529e, 76, Finished, Available, Finished)
# Table Already Exits

# %%
# %%sql
# select count(*) from tbl_latest_news1;
# Out:
# StatementMeta(, 26f212cd-c9af-44d0-a13c-eec767da529e, 77, Finished, Available, Finished)
# <Spark SQL result set with 1 rows and 1 fields>
